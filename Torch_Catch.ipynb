# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
from copy import deepcopy
from PIL import Image
import os 
from torch.nn import parameter
Parameter = parameter.Parameter

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable, Function
import torchvision.transforms as T
from catch import Catch
# if gpu is to be used
use_cuda = torch.cuda.is_available()
FloatTensor = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if use_cuda else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if use_cuda else torch.ByteTensor
Tensor = FloatTensor

# %%
env = gym.make('CartPole-v0').unwrapped

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if gpu is to be used
use_cuda = torch.cuda.is_available()
FloatTensor = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if use_cuda else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if use_cuda else torch.ByteTensor
Tensor = FloatTensor

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):
    def __init__(self, max_memory=100, discount=.9):
        self.max_memory = max_memory
        self.memory = []
        self.discount = discount
        self.current_memory = []

    def push(self, states, game_over, ball_over):
        # memory[i] = [[state_t, action_t, reward_t, state_t+1], game_over?]
        self.current_memory.append([states, game_over])
        if ball_over or game_over:
            self.memory.append(self.current_memory)
            if len(self.memory) > self.max_memory:
                del self.memory[0]
            self.current_memory = []


    def sample(self, model, batch_size=1):
        len_memory = len(self.memory)
        num_actions = model.output_shape[-1]

        Oin = None
        Otar = None
        for i, idx in enumerate(np.random.randint(0, len_memory,
                                                  size=min(len_memory, batch_size))):

            mems = self.memory[idx]
            for mem in mems:
                state_t, action_t, reward_t, state_tp1 = mem[0]
                game_over = mem[1]
                inputs = state_t
                temp_state_t = Variable(torch.from_numpy(state_t).type(Tensor))
                temp_state_tp1 = Variable(torch.from_numpy(state_tp1).type(Tensor))
                
                # There should be no target values for actions not taken.
                # Thou shalt not correct actions not taken #deep
                targets = model(temp_state_t).data.numpy()[0]
                temp_queue = model.save_queue()
                Q_sa = model(temp_state_tp1).data.max(1)[0].view(1, 1).numpy()[0][0]
                model.load_queue(temp_queue)
                
                if game_over:  # if game_over is True
                    targets[action_t] = reward_t
                else:
                    # reward_t + gamma * max_a' Q(s', a')
                    targets[action_t] = reward_t + self.discount * Q_sa
                if Oin is None:
                    Oin = inputs
                    Otar = np.expand_dims(targets, axis=0)
                else:
                    Oin = np.concatenate([Oin, inputs], axis=0)
                    Otar = np.concatenate([Otar, np.expand_dims(targets, axis=0)], axis=0)
            model.reset_queue()
        return Oin, Otar

# %%
class fifo_queue(Function):
    def forward(self, old_queue, inputs):
        outputs = None
        queue = old_queue.clone()
        for temp in inputs:
            queue = torch.cat((queue, temp.unsqueeze(0)), 0)
            queue = queue[1:]
            if outputs is None:
                outputs = queue.clone().unsqueeze(0)
            else:
                outputs = torch.cat((outputs, queue.unsqueeze(0)), 0)
        
        self.mark_non_differentiable(outputs)
        return outputs, queue
    
    def backward(self, output_grad):
        return None


class Queue(nn.Module):
    def __init__(self, input_features, out_features, queue_size, bias=None):
        super(Queue, self).__init__()
        # Setup the Queue
        self.input_features = input_features
        self.queue_size = queue_size
        self.reset_queue()
        
        # Init the queue function
        self.fifo_queue = fifo_queue()

        # Setup the weights to be used in the linear function later. 
        self.weight = Parameter(torch.Tensor(out_features, input_features*queue_size))
        if bias:
            self.bias = Parameter(torch.Tensor(out_features))
        else:
            self.register_parameter('bias', None)
        # Init the parameters
        self.reset_parameters()
        
    def reset_parameters(self):
        stdv = 1. / math.sqrt(self.weight.size(1))
        self.weight.data.uniform_(-stdv, stdv)
        if self.bias is not None:
            self.bias.data.uniform_(-stdv, stdv)
            
    def forward(self, inputs):
        # The actual call that is run when you pass data into this model. 
        
        x = self.fifo_queue(self.queue, inputs)
        output = x[0]
        self.queue = x[1]
        #output, self.queue 
        # Return 
        output = output.view(output.size()[0], -1)
        return F.linear(output, self.weight, self.bias)
            
    # reunit the queue
    def reset_queue(self):
        if type(self.input_features) is list:
            queue = Variable(torch.zeros([self.queue_size]+self.input_features))
        else:
            queue = Variable(torch.zeros([self.queue_size]+[self.input_features]))
        self.queue = queue
        #self.register_buffer("queue", queue)
        self.queue.requires_grad = False
        




"""class Queue(nn.Module):
    def __init__(self, input_features, out_features, queue_size):
        super(Queue, self).__init__()
        self.input_features = input_features
        self.queue_size = queue_size
        # Setup the queue
        if type(input_features) is list:
            self.queue = np.zeros([queue_size]+input_features)
        else:
            self.queue = np.zeros([queue_size]+[input_features])


    def forward(self, inputs):
        # The actual call that is run when you pass data into this model. 
        output = None
        for temp in inputs.data.numpy():
            #print(self.queue[:, 1:].size(), torch.from_numpy(temp).type(Tensor).unsqueeze(0).size())
            self.queue = np.concatenate((self.queue, np.expand_dims(temp, 0)), 0)
            self.queue = self.queue[1:]
            if output is None:
                output = np.expand_dims(self.queue, 0)
            else:
                output = np.concatenate((output, np.expand_dims(self.queue, 0)), 0)
        # Return 
        output = Variable(torch.from_numpy(output).type(Tensor))
        #output.requires_grad = False
        output = output.view(output.size()[0], -1) # FLATTEN and make into a Variable for Torch
        return output
            
    # reunit the queue
    def _reset_queue(self):
        if type(self.input_features) is list:
            self.queue = np.zeros([self.queue_size]+self.input_features)
        else:
            self.queue = np.zeros([self.queue_size]+[self.input_features])
"""
# Out:
# 'class Queue(nn.Module):\n    def __init__(self, input_features, out_features, queue_size):\n        super(Queue, self).__init__()\n        self.input_features = input_features\n        self.queue_size = queue_size\n        # Setup the queue\n        if type(input_features) is list:\n            self.queue = np.zeros([queue_size]+input_features)\n        else:\n            self.queue = np.zeros([queue_size]+[input_features])\n\n\n    def forward(self, inputs):\n        # The actual call that is run when you pass data into this model. \n        output = None\n        for temp in inputs.data.numpy():\n            #print(self.queue[:, 1:].size(), torch.from_numpy(temp).type(Tensor).unsqueeze(0).size())\n            self.queue = np.concatenate((self.queue, np.expand_dims(temp, 0)), 0)\n            self.queue = self.queue[1:]\n            if output is None:\n                output = np.expand_dims(self.queue, 0)\n            else:\n                output = np.concatenate((output, np.expand_dims(self.queue, 0)), 0)\n        # Return \n        output = Variable(torch.from_numpy(output).type(Tensor))\n        #output.requires_grad = False\n        output = output.view(output.size()[0], -1) # FLATTEN and make into a Variable for Torch\n        return output\n            \n    # reunit the queue\n    def _reset_queue(self):\n        if type(self.input_features) is list:\n            self.queue = np.zeros([self.queue_size]+self.input_features)\n        else:\n            self.queue = np.zeros([self.queue_size]+[self.input_features])\n'

# %%
class Queued_DQN(nn.Module):
    def __init__(self, input_size, hidden_size, num_actions, queue_size):
        super(Queued_DQN, self).__init__()
        self.queue = Queue(input_size, input_size*queue_size, queue_size)
        #self.lin1 = nn.Linear(input_size*queue_size, hidden_size)
        self.lin2 = nn.Linear(hidden_size, hidden_size)
        self.lin3 = nn.Linear(hidden_size, num_actions)
        self.output_shape = [1, num_actions]
        
    def forward(self, x):
        # Replace queue with another Linear and you 
        # have the same network we use for everything else. 
        # This is the model
        x = F.relu(self.queue(x))
        #x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        x = self.lin3(x)
        return x
    
    def reset_queue(self):
        self.queue.reset_queue()
        
    def save_queue(self):
        return self.queue.queue.clone()
        
    def load_queue(self, input_queue):
        self.queue.queue = input_queue.clone()

# %%
"""class DQN(nn.Module):
    def __init__(self, input_size, hidden_size, num_actions):
        super(DQN, self).__init__()
        self.lin1 = nn.Linear(input_size, hidden_size)
        self.lin2 = nn.Linear(hidden_size, hidden_size)
        self.lin3 = nn.Linear(hidden_size, num_actions)
        self.output_shape = [1, num_actions]
        
    def forward(self, x):
        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        return self.lin3(x)"""
# Out:
# 'class DQN(nn.Module):\n    def __init__(self, input_size, hidden_size, num_actions):\n        super(DQN, self).__init__()\n        self.lin1 = nn.Linear(input_size, hidden_size)\n        self.lin2 = nn.Linear(hidden_size, hidden_size)\n        self.lin3 = nn.Linear(hidden_size, num_actions)\n        self.output_shape = [1, num_actions]\n        \n    def forward(self, x):\n        x = F.relu(self.lin1(x))\n        x = F.relu(self.lin2(x))\n        return self.lin3(x)'

# %%
import numpy as np
import pandas as pd
def train_catch(catch, model, exp_replay, num_games, batch_size,
                per_random_act=.1, num_actions=3,
                test_every=None, test_on_games=100):
    optimizer = optim.Adagrad(model.parameters())

    # Set up the return Loss and Scores dataframes
    rLoss = pd.DataFrame(columns = ['epoch', 'loss'])
    rLoss['epoch'] = rLoss['epoch'].astype(int)
    # rLoss = pd.DataFrame({'epoch':pd.Series([], dtype='int'), 'loss':pd.Series([], dtype='float')})

    if test_every is not None:
        rScores = pd.DataFrame(columns = ['epoch', str('mean score over ' + str(test_on_games) + ' games')])
        rScores['epoch'] = rLoss['epoch'].astype(int)
    # Record variables for training
    game_cnt = 0
    timestep = 0.0
    counter = 0
    after_first_ball = False
    
    pushed = 0
    
    #train over total epochs
    for e in range(num_games):

        game_over = False
        tot_loss = 0.0

        # get initial input
        input_t = catch.observe(flatten=True, expand_dim=True)
    
        #iterate over each game
        while not game_over:

            # t_-1 is the previous observation
            input_tm1 = input_t.copy()
            # get next action
            temp = torch.from_numpy(input_tm1).type(Tensor)
            temp = Variable(temp)
            q = model(temp).data.max(1)[1].view(1, 1).numpy()
            
            if np.random.rand() <= per_random_act:
                # Randomly pick an action
                action = torch.rand(1) * (num_actions)
                action = int(action.numpy()[0])
            else:
                # Use the pre-selected action
                action = q[0][0]
            # apply action, get rewards and new state
            reward, timestep, game_over = catch.act(action-1)

            # t_0, current timestep
            input_t = catch.observe(flatten=True, expand_dim=True)
            # store experience
            exp_replay.push(states=[input_tm1, action, reward, input_t], game_over=game_over, ball_over=(reward != 0))
            if reward != 0 :
                pushed = pushed + 1
                
            # adapt model
            if pushed >= batch_size + 1: 
                
                temp_queue = model.save_queue()
                for pep in range(batch_size):
                    model.reset_queue()
                    inputs, expected_targets = exp_replay.sample(model, batch_size=1)
                    model.reset_queue()
                    targets = model(Variable(torch.from_numpy(inputs).type(Tensor)))

                    expected_targets = Variable(torch.from_numpy(expected_targets).type(Tensor))

                    # Compute Huber loss
                    loss = F.mse_loss(targets, expected_targets)
                    tot_loss = tot_loss + loss.data.numpy()[0]
                    # Optimize the model
                    optimizer.zero_grad()
                    loss.backward()
                    for param in model.parameters():
                        param.grad.data.clamp_(-1, 1)
                    optimizer.step()

                model.load_queue(temp_queue)

            # game has completed, add one to the total game count
            if game_over:
                game_cnt += 1
                
        if pushed >= batch_size + 1:
            # Save and report loss
            rLoss.loc[len(rLoss), :] = [int(e),loss]
            print("Epoch {:03d} | Loss {:.4f}".format(e, tot_loss))
            # Create initial start environment
        catch.reset()
        model.reset_queue()
        # Test the current model weights if need be.
        if (test_every is not None) and ((e + 1) % test_every == 0):

            scores = test_catch(
                catch=catch, model=model, 
                test_on_games=test_on_games)

            # Save and report mean Score
            ms = scores['score'].mean()
            rScores.loc[len(rScores), :] = [int(e), ms]
            print("Epoch {:03d} | MeanScore {:.2f}".format(e, ms))

            catch.reset()

    # Return rLoss, and rScores if the user requested the model to be tested
    # while training.
    if (test_every is not None):
        return rLoss, rScores
    else:
        return rLoss



def test_catch(catch, model, test_on_games=100,  save_frames=False):

    if save_frames:
        frames_stack = []
    scores = pd.DataFrame(columns=['game', 'score'])
    scores['game'] = scores['game'].astype(int)
    # Iterate over number of games to play
    for game_num in range(test_on_games):

        # Count for num balls that reached the end
        game_over = False

        # Get initial Frame
        frame_num = 1
        input_t = catch.observe(flatten=True, expand_dim=True)
        if save_frames:
            frames_stack.append(input_t)

        total_score = 0
        # Iterate until end of testing game
        while not game_over:

            input_tm1 = input_t

            # Get next action
            temp = torch.from_numpy(input_tm1).type(Tensor)
            temp = Variable(temp)
            q = model(temp).data.max(1)[1].view(1, 1).numpy()
            action = q[0][0]

            # apply action, get rewards and new state
            reward, timestep, game_over = catch.act(action-1)
            input_t = catch.observe(flatten=True, expand_dim=True)
            total_score += reward
            # Iterate frame number
            frame_num += 1

            if save_frames:
                frames_stack.append(input_t)
        scores.loc[len(scores), :] = [int(game_num), total_score]
        #scores.append([game_num, total_score])
        game_num += 1
        catch.reset()
        model.reset_queue()

    if save_frames:
        return scores, frames_stack
    else:
        return scores

# %%
height = 11
width=13
m = 4
q_size = 5
i=0

test_name = "RUN" + str(i) + "_Mask_" + str(int(m)) + "_13x11_Q" + str(q_size)+"_MLP"

c = Catch(screen_height=height, screen_width=width, # output_buffer_size=q_size,
          game_over_conditions = {'ball_deletions': 1}, mask=m, ball_spawn_rate=11,)

exp = ReplayMemory(max_memory=50)

input_size= width * height

model = Queued_DQN(input_size, input_size*q_size, 3, q_size)
#model = DQN(input_size, input_size, 3)

# %%
loss, test_on_train = train_catch(catch = c, model = model, exp_replay = exp, num_games = 5000, 
                                  batch_size = 10, test_every = 5, test_on_games = 100)
c.reset()
tests = test_catch(catch = c, model = model, test_on_games = 1000)
# Out:
# Epoch 004 | MeanScore -0.62
# Epoch 009 | MeanScore -0.46
# Epoch 010 | Loss 1.0657
# Epoch 011 | Loss 2.9893
# Epoch 012 | Loss 0.5993
# Epoch 013 | Loss 0.3263
# Epoch 014 | Loss 0.3325
# Epoch 014 | MeanScore -0.18
# Epoch 015 | Loss 0.1774
# Epoch 016 | Loss 0.0666
# Epoch 017 | Loss 0.1141
# Epoch 018 | Loss 0.0519
# Epoch 019 | Loss 0.4929
# Epoch 019 | MeanScore -0.28
# Epoch 020 | Loss 0.3513
# Epoch 021 | Loss 0.3473
# Epoch 022 | Loss 0.3577
# Epoch 023 | Loss 0.3811
# Epoch 024 | Loss 0.0546
# Epoch 024 | MeanScore -0.28
# Epoch 025 | Loss 0.1277
# Epoch 026 | Loss 0.1865
# Epoch 027 | Loss 0.2945
# Epoch 028 | Loss 0.3003
# Epoch 029 | Loss 0.1108
# Epoch 029 | MeanScore -0.72
# Epoch 030 | Loss 0.1999
# Epoch 031 | Loss 0.2277
# Epoch 032 | Loss 0.1356
# Epoch 033 | Loss 0.1725
# Epoch 034 | Loss 0.0531
# Epoch 034 | MeanScore -0.52
# Epoch 035 | Loss 0.4770
# Epoch 036 | Loss 0.2633
# Epoch 037 | Loss 0.5309
# Epoch 038 | Loss 0.2083
# Epoch 039 | Loss 0.2303
# Epoch 039 | MeanScore -0.46
# Epoch 040 | Loss 0.2679
# Epoch 041 | Loss 0.4901
# Epoch 042 | Loss 0.3600
# Epoch 043 | Loss 0.4695
# Epoch 044 | Loss 0.4082
# Epoch 044 | MeanScore -0.36
# Epoch 045 | Loss 0.5606
# Epoch 046 | Loss 0.2196
# Epoch 047 | Loss 0.2474
# Epoch 048 | Loss 0.2446
# Epoch 049 | Loss 0.1995
# Epoch 049 | MeanScore -0.24
# Epoch 050 | Loss 0.3127
# Epoch 051 | Loss 0.2919
# Epoch 052 | Loss 0.2464
# Epoch 053 | Loss 0.2277
# Epoch 054 | Loss 0.2409
# Epoch 054 | MeanScore -0.38
# Epoch 055 | Loss 0.1332
# Epoch 056 | Loss 0.2391
# Epoch 057 | Loss 0.2182
# Epoch 058 | Loss 0.1746
# Epoch 059 | Loss 0.2060
# Epoch 059 | MeanScore -0.20
# Epoch 060 | Loss 0.1898
# Epoch 061 | Loss 0.1240
# Epoch 062 | Loss 0.0752
# Epoch 063 | Loss 0.0493
# Epoch 064 | Loss 0.0262
# Epoch 064 | MeanScore -0.42
# Epoch 065 | Loss 0.0108
# Epoch 066 | Loss 0.1484
# Epoch 067 | Loss 0.2214
# Epoch 068 | Loss 0.1136
# Epoch 069 | Loss 0.0611
# Epoch 069 | MeanScore -0.38
# Epoch 070 | Loss 0.0483
# Epoch 071 | Loss 0.1305
# Epoch 072 | Loss 0.1666
# Epoch 073 | Loss 0.3170
# Epoch 074 | Loss 0.2439
# Epoch 074 | MeanScore -0.32
# Epoch 075 | Loss 0.1676
# Epoch 076 | Loss 0.0923
# Epoch 077 | Loss 0.1317
# Epoch 078 | Loss 0.0407
# Epoch 079 | Loss 0.0976
# Epoch 079 | MeanScore -0.46
# Epoch 080 | Loss 0.0354
# Epoch 081 | Loss 0.1673
# Epoch 082 | Loss 0.2606
# Epoch 083 | Loss 0.1463
# Epoch 084 | Loss 0.2846
# Epoch 084 | MeanScore -0.32
# Epoch 085 | Loss 0.2449
# Epoch 086 | Loss 0.1354
# Epoch 087 | Loss 0.2066
# Epoch 088 | Loss 0.1032
# Epoch 089 | Loss 0.0951
# Epoch 089 | MeanScore -0.34
# Epoch 090 | Loss 0.0860
# Epoch 091 | Loss 0.0530
# Epoch 092 | Loss 0.0987
# Epoch 093 | Loss 0.0338
# Epoch 094 | Loss 0.1768
# Epoch 094 | MeanScore -0.20
# Epoch 095 | Loss 0.0474
# Epoch 096 | Loss 0.1686
# Epoch 097 | Loss 0.0989
# Epoch 098 | Loss 0.1732
# Epoch 099 | Loss 0.2420
# Epoch 099 | MeanScore -0.40
# Epoch 100 | Loss 0.1716
# Epoch 101 | Loss 0.0655
# Epoch 102 | Loss 0.1295
# Epoch 103 | Loss 0.0412
# Epoch 104 | Loss 0.0303
# Epoch 104 | MeanScore -0.56
# Epoch 105 | Loss 0.0218
# Epoch 106 | Loss 0.0363
# Epoch 107 | Loss 0.0184
# Epoch 108 | Loss 0.4274
# Epoch 109 | Loss 0.2078
# Epoch 109 | MeanScore -0.12
# Epoch 110 | Loss 0.2306
# Epoch 111 | Loss 0.0931
# Epoch 112 | Loss 0.3839
# Epoch 113 | Loss 0.1937
# Epoch 114 | Loss 0.1016
# Epoch 114 | MeanScore -0.12
# Epoch 115 | Loss 0.4481
# Epoch 116 | Loss 0.3769
# Epoch 117 | Loss 0.5696
# Epoch 118 | Loss 0.6015
# Epoch 119 | Loss 0.3918
# Epoch 119 | MeanScore 0.02
# Epoch 120 | Loss 0.3552
# Epoch 121 | Loss 0.1772
# Epoch 122 | Loss 0.3176
# Epoch 123 | Loss 0.3485
# Epoch 124 | Loss 0.2967
# Epoch 124 | MeanScore -0.22
# Epoch 125 | Loss 0.2844
# Epoch 126 | Loss 0.1205
# Epoch 127 | Loss 0.0588
# Epoch 128 | Loss 0.3658
# Epoch 129 | Loss 0.1965
# Epoch 129 | MeanScore -0.30
# Epoch 130 | Loss 0.1000
# Epoch 131 | Loss 0.0592
# Epoch 132 | Loss 0.0835
# Epoch 133 | Loss 0.0503
# Epoch 134 | Loss 0.0863
# Epoch 134 | MeanScore -0.20
# Epoch 135 | Loss 0.0645
# Epoch 136 | Loss 0.0656
# Epoch 137 | Loss 0.1357
# Epoch 138 | Loss 0.0525
# Epoch 139 | Loss 0.0780
# Epoch 139 | MeanScore -0.26
# Epoch 140 | Loss 0.0825
# Epoch 141 | Loss 0.0466
# Epoch 142 | Loss 0.0849
# Epoch 143 | Loss 0.2260
# Epoch 144 | Loss 0.1037
# Epoch 144 | MeanScore -0.12
# Epoch 145 | Loss 0.0695
# Epoch 146 | Loss 0.1400
# Epoch 147 | Loss 0.2351
# Epoch 148 | Loss 0.1172
# Epoch 149 | Loss 0.1882
# Epoch 149 | MeanScore -0.08
# Epoch 150 | Loss 0.0955
# Epoch 151 | Loss 0.1102
# Epoch 152 | Loss 0.1546
# Epoch 153 | Loss 0.0524
# Epoch 154 | Loss 0.0571
# Epoch 154 | MeanScore -0.14
# Epoch 155 | Loss 0.0694
# Epoch 156 | Loss 0.0440
# Epoch 157 | Loss 0.1224
# Epoch 158 | Loss 0.2252
# Epoch 159 | Loss 0.1640
# Epoch 159 | MeanScore -0.22
# Epoch 160 | Loss 0.1402
# Epoch 161 | Loss 0.1036
# Epoch 162 | Loss 0.1353
# Epoch 163 | Loss 0.2673
# Epoch 164 | Loss 0.1123
# Epoch 164 | MeanScore 0.00
# Epoch 165 | Loss 0.3065
# Epoch 166 | Loss 0.1134
# Epoch 167 | Loss 0.1466
# Epoch 168 | Loss 0.1807
# Epoch 169 | Loss 0.2282
# Epoch 169 | MeanScore 0.10
# Epoch 170 | Loss 0.1208
# Epoch 171 | Loss 0.0784
# Epoch 172 | Loss 0.1069
# Epoch 173 | Loss 0.0599
# Epoch 174 | Loss 0.0420
# Epoch 174 | MeanScore 0.24
# Epoch 175 | Loss 0.0843
# Epoch 176 | Loss 0.1784
# Epoch 177 | Loss 0.0358
# Epoch 178 | Loss 0.1011
# Epoch 179 | Loss 0.0603
# Epoch 179 | MeanScore -0.14
# Epoch 180 | Loss 0.0553
# Epoch 181 | Loss 0.0967
# Epoch 182 | Loss 0.0646
# Epoch 183 | Loss 0.0385
# Epoch 184 | Loss 0.1530
# Epoch 184 | MeanScore -0.16
# Epoch 185 | Loss 0.1227
# Epoch 186 | Loss 0.0823
# Epoch 187 | Loss 0.0511
# Epoch 188 | Loss 0.0697
# Epoch 189 | Loss 0.1814
# Epoch 189 | MeanScore -0.08
# Epoch 190 | Loss 0.1404
# Epoch 191 | Loss 0.1199
# Epoch 192 | Loss 0.0506
# Epoch 193 | Loss 0.0579
# Epoch 194 | Loss 0.0480
# Epoch 194 | MeanScore -0.04
# Epoch 195 | Loss 0.0436
# Epoch 196 | Loss 0.0392
# Epoch 197 | Loss 0.0346
# Epoch 198 | Loss 0.0206
# Epoch 199 | Loss 0.1195
# Epoch 199 | MeanScore 0.10
# Epoch 200 | Loss 0.0502
# Epoch 201 | Loss 0.1453
# Epoch 202 | Loss 0.1148
# Epoch 203 | Loss 0.1466
# Epoch 204 | Loss 0.0859
# Epoch 204 | MeanScore -0.08
# Epoch 205 | Loss 0.1717
# Epoch 206 | Loss 0.0688
# Epoch 207 | Loss 0.1267
# Epoch 208 | Loss 0.1744
# Epoch 209 | Loss 0.0863
# Epoch 209 | MeanScore -0.12
# Epoch 210 | Loss 0.1050
# Epoch 211 | Loss 0.0416
# Epoch 212 | Loss 0.4951
# Epoch 213 | Loss 0.3463
# Epoch 214 | Loss 0.1868
# Epoch 214 | MeanScore 0.00
# Epoch 215 | Loss 0.1791
# Epoch 216 | Loss 0.0939
# Epoch 217 | Loss 0.0718
# Epoch 218 | Loss 0.0321
# Epoch 219 | Loss 0.0209
# Epoch 219 | MeanScore 0.02
# Epoch 220 | Loss 0.0327
# Epoch 221 | Loss 0.0372
# Epoch 222 | Loss 0.0443
# Epoch 223 | Loss 0.0970
# Epoch 224 | Loss 0.2512
# Epoch 224 | MeanScore 0.04
# Epoch 225 | Loss 0.1787
# Epoch 226 | Loss 0.0771
# Epoch 227 | Loss 0.0862
# Epoch 228 | Loss 0.0329
# Epoch 229 | Loss 0.0216
# Epoch 229 | MeanScore -0.16
# Epoch 230 | Loss 0.0384
# Epoch 231 | Loss 0.2649
# Epoch 232 | Loss 0.2102
# Epoch 233 | Loss 0.0964
# Epoch 234 | Loss 0.1418
# Epoch 234 | MeanScore 0.08
# Epoch 235 | Loss 0.2924
# Epoch 236 | Loss 0.1189
# Epoch 237 | Loss 0.1411
# Epoch 238 | Loss 0.1638
# Epoch 239 | Loss 0.1964
# Epoch 239 | MeanScore 0.14
# Epoch 240 | Loss 0.1304
# Epoch 241 | Loss 0.1196
# Epoch 242 | Loss 0.0461
# Epoch 243 | Loss 0.0621
# Epoch 244 | Loss 0.0741
# Epoch 244 | MeanScore 0.14
# Epoch 245 | Loss 0.0426
# Epoch 246 | Loss 0.0806
# Epoch 247 | Loss 0.0356
# Epoch 248 | Loss 0.1242
# Epoch 249 | Loss 0.0395
# Epoch 249 | MeanScore 0.26
# Epoch 250 | Loss 0.0401
# Epoch 251 | Loss 0.0359
# Epoch 252 | Loss 0.0162
# Epoch 253 | Loss 0.0699
# Epoch 254 | Loss 0.0546
# Epoch 254 | MeanScore 0.24
# Epoch 255 | Loss 0.0299
# Epoch 256 | Loss 0.0413
# Epoch 257 | Loss 0.0388
# Epoch 258 | Loss 0.0750
# Epoch 259 | Loss 0.1425
# Epoch 259 | MeanScore 0.20
# Epoch 260 | Loss 0.0988
# Epoch 261 | Loss 0.0620
# Epoch 262 | Loss 0.0601
# Epoch 263 | Loss 0.0884
# Epoch 264 | Loss 0.2108
# Epoch 264 | MeanScore 0.10
# Epoch 265 | Loss 0.0456
# Epoch 266 | Loss 0.0337
# Epoch 267 | Loss 0.0410
# Epoch 268 | Loss 0.0601
# Epoch 269 | Loss 0.0409
# Epoch 269 | MeanScore 0.20
# Epoch 270 | Loss 0.0290
# Epoch 271 | Loss 0.0251
# Epoch 272 | Loss 0.3201
# Epoch 273 | Loss 0.1017
# Epoch 274 | Loss 0.0688
# Epoch 274 | MeanScore 0.34
# Epoch 275 | Loss 0.0319
# Epoch 276 | Loss 0.0547
# Epoch 277 | Loss 0.0400
# Epoch 278 | Loss 0.0209
# Epoch 279 | Loss 0.1145
# Epoch 279 | MeanScore 0.08
# Epoch 280 | Loss 0.2226
# Epoch 281 | Loss 0.1025
# Epoch 282 | Loss 0.1056
# Epoch 283 | Loss 0.1083
# Epoch 284 | Loss 0.0508
# Epoch 284 | MeanScore 0.20
# Epoch 285 | Loss 0.0378
# Epoch 286 | Loss 0.0364
# Epoch 287 | Loss 0.1536
# Epoch 288 | Loss 0.1008
# Epoch 289 | Loss 0.1222
# Epoch 289 | MeanScore 0.44
# Epoch 290 | Loss 0.0458
# Epoch 291 | Loss 0.0445
# Epoch 292 | Loss 0.2875
# Epoch 293 | Loss 0.0740
# Epoch 294 | Loss 0.1300
# Epoch 294 | MeanScore 0.30
# Epoch 295 | Loss 0.0753
# Epoch 296 | Loss 0.0884
# Epoch 297 | Loss 0.0567
# Epoch 298 | Loss 0.0563
# Epoch 299 | Loss 0.0553
# Epoch 299 | MeanScore 0.20
# Epoch 300 | Loss 0.0535
# Epoch 301 | Loss 0.0285
# Epoch 302 | Loss 0.0897
# Epoch 303 | Loss 0.0231
# Epoch 304 | Loss 0.0842
# Epoch 304 | MeanScore 0.18
# Epoch 305 | Loss 0.1091
# Epoch 306 | Loss 0.0580
# Epoch 307 | Loss 0.0284
# Epoch 308 | Loss 0.0247
# Epoch 309 | Loss 0.1469
# Epoch 309 | MeanScore 0.34
# Epoch 310 | Loss 0.0903
# Epoch 311 | Loss 0.0629
# Epoch 312 | Loss 0.1101
# Epoch 313 | Loss 0.0596
# Epoch 314 | Loss 0.0595
# Epoch 314 | MeanScore 0.16
# Epoch 315 | Loss 0.0287
# Epoch 316 | Loss 0.0889
# Epoch 317 | Loss 0.0906
# Epoch 318 | Loss 0.0522
# Epoch 319 | Loss 0.1657
# Epoch 319 | MeanScore 0.18
# Epoch 320 | Loss 0.2306
# Epoch 321 | Loss 0.1152
# Epoch 322 | Loss 0.1125
# Epoch 323 | Loss 0.0939
# Epoch 324 | Loss 0.1151
# Epoch 324 | MeanScore 0.38
# Epoch 325 | Loss 0.2370
# Epoch 326 | Loss 0.0821
# Epoch 327 | Loss 0.1139
# Epoch 328 | Loss 0.1043
# Epoch 329 | Loss 0.0383
# Epoch 329 | MeanScore 0.34
# Epoch 330 | Loss 0.0127
# Epoch 331 | Loss 0.0469
# Epoch 332 | Loss 0.0323
# Epoch 333 | Loss 0.0126
# Epoch 334 | Loss 0.1439
# Epoch 334 | MeanScore 0.44
# Epoch 335 | Loss 0.0551
# Epoch 336 | Loss 0.0459
# Epoch 337 | Loss 0.0245
# Epoch 338 | Loss 0.1689
# Epoch 339 | Loss 0.0816
# Epoch 339 | MeanScore 0.34
# Epoch 340 | Loss 0.0340
# Epoch 341 | Loss 0.0712
# Epoch 342 | Loss 0.0239
# Epoch 343 | Loss 0.0312
# Epoch 344 | Loss 0.1691
# Epoch 344 | MeanScore 0.36
# Epoch 345 | Loss 0.2395
# Epoch 346 | Loss 0.1770
# Epoch 347 | Loss 0.1080
# Epoch 348 | Loss 0.1068
# Epoch 349 | Loss 0.0619
# Epoch 349 | MeanScore 0.22
# Epoch 350 | Loss 0.0327
# Epoch 351 | Loss 0.1177
# Epoch 352 | Loss 0.1307
# Epoch 353 | Loss 0.0683
# Epoch 354 | Loss 0.0814
# Epoch 354 | MeanScore 0.42
# Epoch 355 | Loss 0.0292
# Epoch 356 | Loss 0.0349
# Epoch 357 | Loss 0.0389
# Epoch 358 | Loss 0.0410
# Epoch 359 | Loss 0.0177
# Epoch 359 | MeanScore 0.58
# Epoch 360 | Loss 0.0083
# Epoch 361 | Loss 0.0287
# Epoch 362 | Loss 0.0206
# Epoch 363 | Loss 0.1307
# Epoch 364 | Loss 0.1027
# Epoch 364 | MeanScore 0.32
# Epoch 365 | Loss 0.3060
# Epoch 366 | Loss 0.2910
# Epoch 367 | Loss 0.1516
# Epoch 368 | Loss 0.0888
# Epoch 369 | Loss 0.0317
# Epoch 369 | MeanScore 0.26
# Epoch 370 | Loss 0.0568
# Epoch 371 | Loss 0.0311
# Epoch 372 | Loss 0.0756
# Epoch 373 | Loss 0.0372
# Epoch 374 | Loss 0.0235
# Epoch 374 | MeanScore 0.38
# Epoch 375 | Loss 0.1021
# Epoch 376 | Loss 0.0711
# Epoch 377 | Loss 0.0476
# Epoch 378 | Loss 0.0285
# Epoch 379 | Loss 0.0348
# Epoch 379 | MeanScore 0.26
# Epoch 380 | Loss 0.1769
# Epoch 381 | Loss 0.1625
# Epoch 382 | Loss 0.1106
# Epoch 383 | Loss 0.0508
# Epoch 384 | Loss 0.1230
# Epoch 384 | MeanScore 0.24
# Epoch 385 | Loss 0.1780
# Epoch 386 | Loss 0.2664
# Epoch 387 | Loss 0.4024
# Epoch 388 | Loss 0.1560
# Epoch 389 | Loss 0.1515
# Epoch 389 | MeanScore 0.50
# Epoch 390 | Loss 0.1884
# Epoch 391 | Loss 0.2826
# Epoch 392 | Loss 0.1241
# Epoch 393 | Loss 0.0664
# Epoch 394 | Loss 0.1053
# Epoch 394 | MeanScore 0.44
# Epoch 395 | Loss 0.0404
# Epoch 396 | Loss 0.0338
# Epoch 397 | Loss 0.0184
# Epoch 398 | Loss 0.1176
# Epoch 399 | Loss 0.1228
# Epoch 399 | MeanScore 0.38
# Epoch 400 | Loss 0.0752
# Epoch 401 | Loss 0.1040
# Epoch 402 | Loss 0.0466
# Epoch 403 | Loss 0.0744
# Epoch 404 | Loss 0.0412
# Epoch 404 | MeanScore 0.44
# Epoch 405 | Loss 0.0236
# Epoch 406 | Loss 0.0377
# Epoch 407 | Loss 0.0250
# Epoch 408 | Loss 0.0212
# Epoch 409 | Loss 0.0248
# Epoch 409 | MeanScore 0.46
# Epoch 410 | Loss 0.0296
# Epoch 411 | Loss 0.0245
# Epoch 412 | Loss 0.0103
# Epoch 413 | Loss 0.0204
# Epoch 414 | Loss 0.0223
# Epoch 414 | MeanScore 0.56
# Epoch 415 | Loss 0.1013
# Epoch 416 | Loss 0.1680
# Epoch 417 | Loss 0.0498
# Epoch 418 | Loss 0.0751
# Epoch 419 | Loss 0.0154
# Epoch 419 | MeanScore 0.32
# Epoch 420 | Loss 0.0530
# Epoch 421 | Loss 0.0450
# Epoch 422 | Loss 0.0944
# Epoch 423 | Loss 0.0517
# Epoch 424 | Loss 0.0317
# Epoch 424 | MeanScore 0.42
# Epoch 425 | Loss 0.0557
# Epoch 426 | Loss 0.0939
# Epoch 427 | Loss 0.0776
# Epoch 428 | Loss 0.0753
# Epoch 429 | Loss 0.0592
# Epoch 429 | MeanScore 0.34
# Epoch 430 | Loss 0.1350
# Epoch 431 | Loss 0.0272
# Epoch 432 | Loss 0.0371
# Epoch 433 | Loss 0.0241
# Epoch 434 | Loss 0.0279
# Epoch 434 | MeanScore 0.48
# Epoch 435 | Loss 0.0163
# Epoch 436 | Loss 0.0313
# Epoch 437 | Loss 0.0323
# Epoch 438 | Loss 0.0572
# Epoch 439 | Loss 0.0232
# Epoch 439 | MeanScore 0.30
# Epoch 440 | Loss 0.0275
# Epoch 441 | Loss 0.0225
# Epoch 442 | Loss 0.1272
# Epoch 443 | Loss 0.1462
# Epoch 444 | Loss 0.0473
# Epoch 444 | MeanScore 0.40
# Epoch 445 | Loss 0.0765
# Epoch 446 | Loss 0.0300
# Epoch 447 | Loss 0.1050
# Epoch 448 | Loss 0.0744
# Epoch 449 | Loss 0.0347
# Epoch 449 | MeanScore 0.36
# Epoch 450 | Loss 0.0307
# Epoch 451 | Loss 0.0208
# Epoch 452 | Loss 0.0234
# Epoch 453 | Loss 0.1184
# Epoch 454 | Loss 0.0371
# Epoch 454 | MeanScore 0.36
# Epoch 455 | Loss 0.0580
# Epoch 456 | Loss 0.1186
# Epoch 457 | Loss 0.0686
# Epoch 458 | Loss 0.0341
# Epoch 459 | Loss 0.0176
# Epoch 459 | MeanScore 0.48
# Epoch 460 | Loss 0.0582
# Epoch 461 | Loss 0.0420
# Epoch 462 | Loss 0.0311
# Epoch 463 | Loss 0.0538
# Epoch 464 | Loss 0.0676
# Epoch 464 | MeanScore 0.32
# Epoch 465 | Loss 0.0502
# Epoch 466 | Loss 0.1863
# Epoch 467 | Loss 0.0911
# Epoch 468 | Loss 0.1207
# Epoch 469 | Loss 0.0649
# Epoch 469 | MeanScore 0.70
# Epoch 470 | Loss 0.0216
# Epoch 471 | Loss 0.0299
# Epoch 472 | Loss 0.0468
# Epoch 473 | Loss 0.0232
# Epoch 474 | Loss 0.0381
# Epoch 474 | MeanScore 0.44
# Epoch 475 | Loss 0.0509
# Epoch 476 | Loss 0.0218
# Epoch 477 | Loss 0.0202
# Epoch 478 | Loss 0.0081
# Epoch 479 | Loss 0.0208
# Epoch 479 | MeanScore 0.46
# Epoch 480 | Loss 0.0118
# Epoch 481 | Loss 0.0168
# Epoch 482 | Loss 0.0176
# Epoch 483 | Loss 0.0178
# Epoch 484 | Loss 0.0166
# Epoch 484 | MeanScore 0.52
# Epoch 485 | Loss 0.0258
# Epoch 486 | Loss 0.0955
# Epoch 487 | Loss 0.0264
# Epoch 488 | Loss 0.0353
# Epoch 489 | Loss 0.0238
# Epoch 489 | MeanScore 0.50
# Epoch 490 | Loss 0.0156
# Epoch 491 | Loss 0.0084
# Epoch 492 | Loss 0.0243
# Epoch 493 | Loss 0.1663
# Epoch 494 | Loss 0.0867
# Epoch 494 | MeanScore 0.58
# Epoch 495 | Loss 0.0385
# Epoch 496 | Loss 0.0599
# Epoch 497 | Loss 0.0321
# Epoch 498 | Loss 0.0475
# Epoch 499 | Loss 0.0217
# Epoch 499 | MeanScore 0.58
# Epoch 500 | Loss 0.0460
# Epoch 501 | Loss 0.0415
# Epoch 502 | Loss 0.0172
# Epoch 503 | Loss 0.0116
# Epoch 504 | Loss 0.0411
# Epoch 504 | MeanScore 0.48
# Epoch 505 | Loss 0.0629
# Epoch 506 | Loss 0.0259
# Epoch 507 | Loss 0.0135
# Epoch 508 | Loss 0.0077
# Epoch 509 | Loss 0.0673
# Epoch 509 | MeanScore 0.36
# Epoch 510 | Loss 0.0311
# Epoch 511 | Loss 0.0228
# Epoch 512 | Loss 0.0696
# Epoch 513 | Loss 0.0352
# Epoch 514 | Loss 0.0425
# Epoch 514 | MeanScore 0.46
# Epoch 515 | Loss 0.1396
# Epoch 516 | Loss 0.0460
# Epoch 517 | Loss 0.0363
# Epoch 518 | Loss 0.1312
# Epoch 519 | Loss 0.0716
# Epoch 519 | MeanScore 0.52
# Epoch 520 | Loss 0.1147
# Epoch 521 | Loss 0.1185
# Epoch 522 | Loss 0.0859
# Epoch 523 | Loss 0.0158
# Epoch 524 | Loss 0.0469
# Epoch 524 | MeanScore 0.60
# Epoch 525 | Loss 0.0440
# Epoch 526 | Loss 0.0617
# Epoch 527 | Loss 0.0209
# Epoch 528 | Loss 0.0100
# Epoch 529 | Loss 0.0354
# Epoch 529 | MeanScore 0.58
# Epoch 530 | Loss 0.0211
# Epoch 531 | Loss 0.0169
# Epoch 532 | Loss 0.0092
# Epoch 533 | Loss 0.0260
# Epoch 534 | Loss 0.0261
# Epoch 534 | MeanScore 0.50
# Epoch 535 | Loss 0.0338
# Epoch 536 | Loss 0.2960
# Epoch 537 | Loss 0.0707
# Epoch 538 | Loss 0.0806
# Epoch 539 | Loss 0.0667
# Epoch 539 | MeanScore 0.52
# Epoch 540 | Loss 0.1372
# Epoch 541 | Loss 0.0511
# Epoch 542 | Loss 0.0341
# Epoch 543 | Loss 0.0352
# Epoch 544 | Loss 0.0473
# Epoch 544 | MeanScore 0.60
# Epoch 545 | Loss 0.0414
# Epoch 546 | Loss 0.0623
# Epoch 547 | Loss 0.0613
# Epoch 548 | Loss 0.0259
# Epoch 549 | Loss 0.0496
# Epoch 549 | MeanScore 0.68
# Epoch 550 | Loss 0.0222
# Epoch 551 | Loss 0.0136
# Epoch 552 | Loss 0.0157
# Epoch 553 | Loss 0.0348
# Epoch 554 | Loss 0.0431
# Epoch 554 | MeanScore 0.70
# Epoch 555 | Loss 0.0210
# Epoch 556 | Loss 0.0575
# Epoch 557 | Loss 0.0652
# Epoch 558 | Loss 0.0272
# Epoch 559 | Loss 0.0315
# Epoch 559 | MeanScore 0.70
# Epoch 560 | Loss 0.0111
# Epoch 561 | Loss 0.0426
# Epoch 562 | Loss 0.0117
# Epoch 563 | Loss 0.0260
# Epoch 564 | Loss 0.0249
# Epoch 564 | MeanScore 0.64
# Epoch 565 | Loss 0.0216
# Epoch 566 | Loss 0.0467
# Epoch 567 | Loss 0.0151
# Epoch 568 | Loss 0.1116
# Epoch 569 | Loss 0.0553
# Epoch 569 | MeanScore 0.80
# Epoch 570 | Loss 0.0100
# Epoch 571 | Loss 0.1418
# Epoch 572 | Loss 0.0556
# Epoch 573 | Loss 0.0320
# Epoch 574 | Loss 0.0237
# Epoch 574 | MeanScore 0.64
# Epoch 575 | Loss 0.0959
# Epoch 576 | Loss 0.1141
# Epoch 577 | Loss 0.0718
# Epoch 578 | Loss 0.0508
# Epoch 579 | Loss 0.0533
# Epoch 579 | MeanScore 0.76
# Epoch 580 | Loss 0.0319
# Epoch 581 | Loss 0.0574
# Epoch 582 | Loss 0.1003
# Epoch 583 | Loss 0.1087
# Epoch 584 | Loss 0.0435
# Epoch 584 | MeanScore 0.70
# Epoch 585 | Loss 0.0234
# Epoch 586 | Loss 0.0222
# Epoch 587 | Loss 0.0145
# Epoch 588 | Loss 0.0308
# Epoch 589 | Loss 0.0227
# Epoch 589 | MeanScore 0.52
# Epoch 590 | Loss 0.0087
# Epoch 591 | Loss 0.0308
# Epoch 592 | Loss 0.0148
# Epoch 593 | Loss 0.0110
# Epoch 594 | Loss 0.0069
# Epoch 594 | MeanScore 0.52
# Epoch 595 | Loss 0.0036
# Epoch 596 | Loss 0.0036
# Epoch 597 | Loss 0.0639
# Epoch 598 | Loss 0.0267
# Epoch 599 | Loss 0.0515
# Epoch 599 | MeanScore 0.72
# Epoch 600 | Loss 0.0308
# Epoch 601 | Loss 0.0201
# Epoch 602 | Loss 0.0456
# Epoch 603 | Loss 0.0474
# Epoch 604 | Loss 0.0311
# Epoch 604 | MeanScore 0.60
# Epoch 605 | Loss 0.0217
# Epoch 606 | Loss 0.0187
# Epoch 607 | Loss 0.0087
# Epoch 608 | Loss 0.0122
# Epoch 609 | Loss 0.0225
# Epoch 609 | MeanScore 0.72
# Epoch 610 | Loss 0.0312
# Epoch 611 | Loss 0.0421
# Epoch 612 | Loss 0.0181
# Epoch 613 | Loss 0.0119
# Epoch 614 | Loss 0.0086
# Epoch 614 | MeanScore 0.78
# Epoch 615 | Loss 0.0175
# Epoch 616 | Loss 0.0096
# Epoch 617 | Loss 0.0114
# Epoch 618 | Loss 0.0146
# Epoch 619 | Loss 0.0022
# Epoch 619 | MeanScore 0.74
# Epoch 620 | Loss 0.0149
# Epoch 621 | Loss 0.0015
# Epoch 622 | Loss 0.0357
# Epoch 623 | Loss 0.0642
# Epoch 624 | Loss 0.0254
# Epoch 624 | MeanScore 0.72
# Epoch 625 | Loss 0.0130
# Epoch 626 | Loss 0.0088
# Epoch 627 | Loss 0.0058
# Epoch 628 | Loss 0.0052
# Epoch 629 | Loss 0.0712
# Epoch 629 | MeanScore 0.74
# Epoch 630 | Loss 0.0188
# Epoch 631 | Loss 0.0247
# Epoch 632 | Loss 0.0096
# Epoch 633 | Loss 0.0315
# Epoch 634 | Loss 0.0121
# Epoch 634 | MeanScore 0.66
# Epoch 635 | Loss 0.0059
# Epoch 636 | Loss 0.0096
# Epoch 637 | Loss 0.0159
# Epoch 638 | Loss 0.0078
# Epoch 639 | Loss 0.0380
# Epoch 639 | MeanScore 0.64
# Epoch 640 | Loss 0.0155
# Epoch 641 | Loss 0.0189
# Epoch 642 | Loss 0.1833
# Epoch 643 | Loss 0.0785
# Epoch 644 | Loss 0.0842
# Epoch 644 | MeanScore 0.60
# Epoch 645 | Loss 0.1334
# Epoch 646 | Loss 0.1026
# Epoch 647 | Loss 0.1464
# Epoch 648 | Loss 0.0678
# Epoch 649 | Loss 0.0320
# Epoch 649 | MeanScore 0.68
# Epoch 650 | Loss 0.0326
# Epoch 651 | Loss 0.0309
# Epoch 652 | Loss 0.0240
# Epoch 653 | Loss 0.0304
# Epoch 654 | Loss 0.0211
# Epoch 654 | MeanScore 0.64
# Epoch 655 | Loss 0.0379
# Epoch 656 | Loss 0.0702
# Epoch 657 | Loss 0.0619
# Epoch 658 | Loss 0.0311
# Epoch 659 | Loss 0.0312
# Epoch 659 | MeanScore 0.68
# Epoch 660 | Loss 0.0305
# Epoch 661 | Loss 0.0370
# Epoch 662 | Loss 0.0231
# Epoch 663 | Loss 0.0537
# Epoch 664 | Loss 0.0357
# Epoch 664 | MeanScore 0.68
# Epoch 665 | Loss 0.3339
# Epoch 666 | Loss 0.1558
# Epoch 667 | Loss 0.0447
# Epoch 668 | Loss 0.0425
# Epoch 669 | Loss 0.0605
# Epoch 669 | MeanScore 0.76
# Epoch 670 | Loss 0.0447
# Epoch 671 | Loss 0.0244
# Epoch 672 | Loss 0.0221
# Epoch 673 | Loss 0.0263
# Epoch 674 | Loss 0.0374
# Epoch 674 | MeanScore 0.80
# Epoch 675 | Loss 0.0641
# Epoch 676 | Loss 0.0300
# Epoch 677 | Loss 0.0324
# Epoch 678 | Loss 0.0296
# Epoch 679 | Loss 0.0325
# Epoch 679 | MeanScore 0.78
# Epoch 680 | Loss 0.0218
# Epoch 681 | Loss 0.0432
# Epoch 682 | Loss 0.0414
# Epoch 683 | Loss 0.0129
# Epoch 684 | Loss 0.1188
# Epoch 684 | MeanScore 0.88
# Epoch 685 | Loss 0.1828
# Epoch 686 | Loss 0.1670
# Epoch 687 | Loss 0.0359
# Epoch 688 | Loss 0.0299
# Epoch 689 | Loss 0.0330
# Epoch 689 | MeanScore 0.76
# Epoch 690 | Loss 0.0191
# Epoch 691 | Loss 0.0110
# Epoch 692 | Loss 0.0112
# Epoch 693 | Loss 0.0294
# Epoch 694 | Loss 0.0169
# Epoch 694 | MeanScore 0.66
# Epoch 695 | Loss 0.1652
# Epoch 696 | Loss 0.0242
# Epoch 697 | Loss 0.0338
# Epoch 698 | Loss 0.1311
# Epoch 699 | Loss 0.0425
# Epoch 699 | MeanScore 0.78
# Epoch 700 | Loss 0.0251
# Epoch 701 | Loss 0.0272
# Epoch 702 | Loss 0.0149
# Epoch 703 | Loss 0.0222
# Epoch 704 | Loss 0.0145
# Epoch 704 | MeanScore 0.66
# Epoch 705 | Loss 0.0095
# Epoch 706 | Loss 0.0147
# Epoch 707 | Loss 0.0114
# Epoch 708 | Loss 0.0184
# Epoch 709 | Loss 0.0512
# Epoch 709 | MeanScore 0.78
# Epoch 710 | Loss 0.0368
# Epoch 711 | Loss 0.0186
# Epoch 712 | Loss 0.0563
# Epoch 713 | Loss 0.0332
# Epoch 714 | Loss 0.0236
# Epoch 714 | MeanScore 0.72
# Epoch 715 | Loss 0.0170
# Epoch 716 | Loss 0.0127
# Epoch 717 | Loss 0.0213
# Epoch 718 | Loss 0.0144
# Epoch 719 | Loss 0.0172
# Epoch 719 | MeanScore 0.78
# Epoch 720 | Loss 0.0095
# Epoch 721 | Loss 0.0140
# Epoch 722 | Loss 0.0881
# Epoch 723 | Loss 0.0466
# Epoch 724 | Loss 0.0686
# Epoch 724 | MeanScore 0.78
# Epoch 725 | Loss 0.0670
# Epoch 726 | Loss 0.0283
# Epoch 727 | Loss 0.0094
# Epoch 728 | Loss 0.0301
# Epoch 729 | Loss 0.0137
# Epoch 729 | MeanScore 0.68
# Epoch 730 | Loss 0.0111
# Epoch 731 | Loss 0.0116
# Epoch 732 | Loss 0.0076
# Epoch 733 | Loss 0.0075
# Epoch 734 | Loss 0.0242
# Epoch 734 | MeanScore 0.84
# Epoch 735 | Loss 0.0063
# Epoch 736 | Loss 0.1013
# Epoch 737 | Loss 0.1016
# Epoch 738 | Loss 0.0586
# Epoch 739 | Loss 0.0230
# Epoch 739 | MeanScore 0.68
# Epoch 740 | Loss 0.0234
# Epoch 741 | Loss 0.0124
# Epoch 742 | Loss 0.0231
# Epoch 743 | Loss 0.0124
# Epoch 744 | Loss 0.0117
# Epoch 744 | MeanScore 0.78
# Epoch 745 | Loss 0.0090
# Epoch 746 | Loss 0.0076
# Epoch 747 | Loss 0.0041
# Epoch 748 | Loss 0.0267
# Epoch 749 | Loss 0.0285
# Epoch 749 | MeanScore 0.82
# Epoch 750 | Loss 0.0215
# Epoch 751 | Loss 0.0098
# Epoch 752 | Loss 0.0159
# Epoch 753 | Loss 0.0147
# Epoch 754 | Loss 0.0126
# Epoch 754 | MeanScore 0.76
# Epoch 755 | Loss 0.0052
# Epoch 756 | Loss 0.0260
# Epoch 757 | Loss 0.0263
# Epoch 758 | Loss 0.0171
# Epoch 759 | Loss 0.0072
# Epoch 759 | MeanScore 0.82
# Epoch 760 | Loss 0.0216
# Epoch 761 | Loss 0.0398
# Epoch 762 | Loss 0.0377
# Epoch 763 | Loss 0.0288
# Epoch 764 | Loss 0.0154
# Epoch 764 | MeanScore 0.86
# Epoch 765 | Loss 0.0062
# Epoch 766 | Loss 0.0367
# Epoch 767 | Loss 0.0300
# Epoch 768 | Loss 0.2248
# Epoch 769 | Loss 0.0252
# Epoch 769 | MeanScore 0.80
# Epoch 770 | Loss 0.0120
# Epoch 771 | Loss 0.0531
# Epoch 772 | Loss 0.1954
# Epoch 773 | Loss 0.0513
# Epoch 774 | Loss 0.0207
# Epoch 774 | MeanScore 0.74
# Epoch 775 | Loss 0.0134
# Epoch 776 | Loss 0.0086
# Epoch 777 | Loss 0.0089
# Epoch 778 | Loss 0.0096
# Epoch 779 | Loss 0.0079
# Epoch 779 | MeanScore 0.80
# Epoch 780 | Loss 0.0203
# Epoch 781 | Loss 0.0404
# Epoch 782 | Loss 0.0577
# Epoch 783 | Loss 0.0204
# Epoch 784 | Loss 0.1702
# Epoch 784 | MeanScore 0.86
# Epoch 785 | Loss 0.2266
# Epoch 786 | Loss 0.3279
# Epoch 787 | Loss 0.1385
# Epoch 788 | Loss 0.0437
# Epoch 789 | Loss 0.0407
# Epoch 789 | MeanScore 0.74
# Epoch 790 | Loss 0.0417
# Epoch 791 | Loss 0.0167
# Epoch 792 | Loss 0.0070
# Epoch 793 | Loss 0.1867
# Epoch 794 | Loss 0.0305
# Epoch 794 | MeanScore 0.60
# Epoch 795 | Loss 0.0523
# Epoch 796 | Loss 0.0292
# Epoch 797 | Loss 0.1721
# Epoch 798 | Loss 0.0650
# Epoch 799 | Loss 0.0844
# Epoch 799 | MeanScore 0.74
# Epoch 800 | Loss 0.0298
# Epoch 801 | Loss 0.0681
# Epoch 802 | Loss 0.0421
# Epoch 803 | Loss 0.0131
# Epoch 804 | Loss 0.0135
# Epoch 804 | MeanScore 0.82
# Epoch 805 | Loss 0.0773
# Epoch 806 | Loss 0.0620
# Epoch 807 | Loss 0.0149
# Epoch 808 | Loss 0.0187
# Epoch 809 | Loss 0.0164
# Epoch 809 | MeanScore 0.86
# Epoch 810 | Loss 0.0076
# Epoch 811 | Loss 0.0104
# Epoch 812 | Loss 0.0685
# Epoch 813 | Loss 0.0202
# Epoch 814 | Loss 0.0699
# Epoch 814 | MeanScore 0.82
# Epoch 815 | Loss 0.0317
# Epoch 816 | Loss 0.0256
# Epoch 817 | Loss 0.0245
# Epoch 818 | Loss 0.0078
# Epoch 819 | Loss 0.0083
# Epoch 819 | MeanScore 0.74
# Epoch 820 | Loss 0.0354
# Epoch 821 | Loss 0.1468
# Epoch 822 | Loss 0.0452
# Epoch 823 | Loss 0.0319
# Epoch 824 | Loss 0.1058
# Epoch 824 | MeanScore 0.70
# Epoch 825 | Loss 0.0720
# Epoch 826 | Loss 0.0378
# Epoch 827 | Loss 0.0339
# Epoch 828 | Loss 0.0177
# Epoch 829 | Loss 0.0556
# Epoch 829 | MeanScore 0.72
# Epoch 830 | Loss 0.0276
# Epoch 831 | Loss 0.0473
# Epoch 832 | Loss 0.1807
# Epoch 833 | Loss 0.1813
# Epoch 834 | Loss 0.0406
# Epoch 834 | MeanScore 0.82
# Epoch 835 | Loss 0.3299
# Epoch 836 | Loss 0.0455
# Epoch 837 | Loss 0.0306
# Epoch 838 | Loss 0.1648
# Epoch 839 | Loss 0.0343
# Epoch 839 | MeanScore 0.84
# Epoch 840 | Loss 0.0483
# Epoch 841 | Loss 0.0439
# Epoch 842 | Loss 0.0649
# Epoch 843 | Loss 0.0210
# Epoch 844 | Loss 0.1298
# Epoch 844 | MeanScore 0.78
# Epoch 845 | Loss 0.0515
# Epoch 846 | Loss 0.0315
# Epoch 847 | Loss 0.0367
# Epoch 848 | Loss 0.0261
# Epoch 849 | Loss 0.0191
# Epoch 849 | MeanScore 0.82
# Epoch 850 | Loss 0.0083
# Epoch 851 | Loss 0.0113
# Epoch 852 | Loss 0.0173
# Epoch 853 | Loss 0.0092
# Epoch 854 | Loss 0.0090
# Epoch 854 | MeanScore 0.94
# Epoch 855 | Loss 0.0051
# Epoch 856 | Loss 0.0714
# Epoch 857 | Loss 0.0460
# Epoch 858 | Loss 0.0176
# Epoch 859 | Loss 0.1344
# Epoch 859 | MeanScore 0.88
# Epoch 860 | Loss 0.0112
# Epoch 861 | Loss 0.0140
# Epoch 862 | Loss 0.0143
# Epoch 863 | Loss 0.0294
# Epoch 864 | Loss 0.0119
# Epoch 864 | MeanScore 0.84
# Epoch 865 | Loss 0.0131
# Epoch 866 | Loss 0.0125
# Epoch 867 | Loss 0.0052
# Epoch 868 | Loss 0.0060
# Epoch 869 | Loss 0.0509
# Epoch 869 | MeanScore 0.92
# Epoch 870 | Loss 0.0431
# Epoch 871 | Loss 0.0276
# Epoch 872 | Loss 0.0242
# Epoch 873 | Loss 0.0272
# Epoch 874 | Loss 0.0332
# Epoch 874 | MeanScore 0.86
# Epoch 875 | Loss 0.0430
# Epoch 876 | Loss 0.0162
# Epoch 877 | Loss 0.0233
# Epoch 878 | Loss 0.0105
# Epoch 879 | Loss 0.0369
# Epoch 879 | MeanScore 0.88
# Epoch 880 | Loss 0.0206
# Epoch 881 | Loss 0.0164
# Epoch 882 | Loss 0.1790
# Epoch 883 | Loss 0.0105
# Epoch 884 | Loss 0.0380
# Epoch 884 | MeanScore 0.76
# Epoch 885 | Loss 0.1542
# Epoch 886 | Loss 0.0460
# Epoch 887 | Loss 0.0416
# Epoch 888 | Loss 0.0175
# Epoch 889 | Loss 0.0119
# Epoch 889 | MeanScore 0.94
# Epoch 890 | Loss 0.0055
# Epoch 891 | Loss 0.0114
# Epoch 892 | Loss 0.0147
# Epoch 893 | Loss 0.0129
# Epoch 894 | Loss 0.0073
# Epoch 894 | MeanScore 0.74
# Epoch 895 | Loss 0.0053
# Epoch 896 | Loss 0.0037
# Epoch 897 | Loss 0.1427
# Epoch 898 | Loss 0.0804
# Epoch 899 | Loss 0.0306
# Epoch 899 | MeanScore 0.82
# Epoch 900 | Loss 0.0140
# Epoch 901 | Loss 0.0343
# Epoch 902 | Loss 0.0107
# Epoch 903 | Loss 0.0461
# Epoch 904 | Loss 0.0184
# Epoch 904 | MeanScore 0.80
# Epoch 905 | Loss 0.0090
# Epoch 906 | Loss 0.0146
# Epoch 907 | Loss 0.0198
# Epoch 908 | Loss 0.0117
# Epoch 909 | Loss 0.0087
# Epoch 909 | MeanScore 0.84
# Epoch 910 | Loss 0.0058
# Epoch 911 | Loss 0.0095
# Epoch 912 | Loss 0.0045
# Epoch 913 | Loss 0.1390
# Epoch 914 | Loss 0.0179
# Epoch 914 | MeanScore 0.80
# Epoch 915 | Loss 0.0280
# Epoch 916 | Loss 0.0317
# Epoch 917 | Loss 0.0332
# Epoch 918 | Loss 0.0150
# Epoch 919 | Loss 0.0688
# Epoch 919 | MeanScore 0.80
# Epoch 920 | Loss 0.0359
# Epoch 921 | Loss 0.0183
# Epoch 922 | Loss 0.0086
# Epoch 923 | Loss 0.0101
# Epoch 924 | Loss 0.0405
# Epoch 924 | MeanScore 0.72
# Epoch 925 | Loss 0.0544
# Epoch 926 | Loss 0.0213
# Epoch 927 | Loss 0.0143
# Epoch 928 | Loss 0.0085
# Epoch 929 | Loss 0.0033
# Epoch 929 | MeanScore 0.74
# Epoch 930 | Loss 0.0362
# Epoch 931 | Loss 0.0491
# Epoch 932 | Loss 0.0312
# Epoch 933 | Loss 0.0157
# Epoch 934 | Loss 0.0121
# Epoch 934 | MeanScore 0.90
# Epoch 935 | Loss 0.0082
# Epoch 936 | Loss 0.0056
# Epoch 937 | Loss 0.0095
# Epoch 938 | Loss 0.0336
# Epoch 939 | Loss 0.0265
# Epoch 939 | MeanScore 0.88
# Epoch 940 | Loss 0.0208
# Epoch 941 | Loss 0.0171
# Epoch 942 | Loss 0.0076
# Epoch 943 | Loss 0.0261
# Epoch 944 | Loss 0.0427
# Epoch 944 | MeanScore 0.70
# Epoch 945 | Loss 0.0307
# Epoch 946 | Loss 0.0349
# Epoch 947 | Loss 0.0200
# Epoch 948 | Loss 0.0428
# Epoch 949 | Loss 0.0155
# Epoch 949 | MeanScore 0.74
# Epoch 950 | Loss 0.0187
# Epoch 951 | Loss 0.2038
# Epoch 952 | Loss 0.0651
# Epoch 953 | Loss 0.0471
# Epoch 954 | Loss 0.0501
# Epoch 954 | MeanScore 0.84
# Epoch 955 | Loss 0.0203
# Epoch 956 | Loss 0.0325
# Epoch 957 | Loss 0.0254
# Epoch 958 | Loss 0.0234
# Epoch 959 | Loss 0.0146
# Epoch 959 | MeanScore 0.84
# Epoch 960 | Loss 0.0365
# Epoch 961 | Loss 0.0098
# Epoch 962 | Loss 0.0273
# Epoch 963 | Loss 0.1061
# Epoch 964 | Loss 0.0386
# Epoch 964 | MeanScore 0.74
# Epoch 965 | Loss 0.0289
# Epoch 966 | Loss 0.1099
# Epoch 967 | Loss 0.0495
# Epoch 968 | Loss 0.0277
# Epoch 969 | Loss 0.0287
# Epoch 969 | MeanScore 0.72
# Epoch 970 | Loss 0.0253
# Epoch 971 | Loss 0.0131
# Epoch 972 | Loss 0.0270
# Epoch 973 | Loss 0.0178
# Epoch 974 | Loss 0.0104
# Epoch 974 | MeanScore 0.94
# Epoch 975 | Loss 0.0181
# Epoch 976 | Loss 0.0155
# Epoch 977 | Loss 0.1122
# Epoch 978 | Loss 0.0466
# Epoch 979 | Loss 0.0215
# Epoch 979 | MeanScore 0.84
# Epoch 980 | Loss 0.0373
# Epoch 981 | Loss 0.0130
# Epoch 982 | Loss 0.0331
# Epoch 983 | Loss 0.0207
# Epoch 984 | Loss 0.0218
# Epoch 984 | MeanScore 0.88
# Epoch 985 | Loss 0.0164
# Epoch 986 | Loss 0.0081
# Epoch 987 | Loss 0.0932
# Epoch 988 | Loss 0.0366
# Epoch 989 | Loss 0.0155
# Epoch 989 | MeanScore 0.82
# Epoch 990 | Loss 0.0108
# Epoch 991 | Loss 0.0133
# Epoch 992 | Loss 0.0078
# Epoch 993 | Loss 0.0087
# Epoch 994 | Loss 0.0038
# Epoch 994 | MeanScore 0.90
# Epoch 995 | Loss 0.0136
# Epoch 996 | Loss 0.0088
# Epoch 997 | Loss 0.0105
# Epoch 998 | Loss 0.0307
# Epoch 999 | Loss 0.0157
# Epoch 999 | MeanScore 0.82
# Epoch 1000 | Loss 0.0109
# Epoch 1001 | Loss 0.0087
# Epoch 1002 | Loss 0.0046
# Epoch 1003 | Loss 0.0071
# Epoch 1004 | Loss 0.0624
# Epoch 1004 | MeanScore 0.90
# Epoch 1005 | Loss 0.0478
# Epoch 1006 | Loss 0.0111
# Epoch 1007 | Loss 0.0112
# Epoch 1008 | Loss 0.0122
# Epoch 1009 | Loss 0.0132
# Epoch 1009 | MeanScore 0.96
# Epoch 1010 | Loss 0.0068
# Epoch 1011 | Loss 0.2371
# Epoch 1012 | Loss 0.1654
# Epoch 1013 | Loss 0.0600
# Epoch 1014 | Loss 0.0671
# Epoch 1014 | MeanScore 0.92
# Epoch 1015 | Loss 0.0198
# Epoch 1016 | Loss 0.0138
# Epoch 1017 | Loss 0.0070
# Epoch 1018 | Loss 0.0385
# Epoch 1019 | Loss 0.1132
# Epoch 1019 | MeanScore 0.94
# Epoch 1695 | Loss 0.0185
# Epoch 1696 | Loss 0.0166
# Epoch 1697 | Loss 0.0110
# Epoch 1698 | Loss 0.0190
# Epoch 1699 | Loss 0.0096
# Epoch 1699 | MeanScore 0.96
# Epoch 1700 | Loss 0.0074
# Epoch 1701 | Loss 0.0461
# Epoch 1702 | Loss 0.0411
# Epoch 1703 | Loss 0.0188
# Epoch 1704 | Loss 0.0106
# Epoch 1704 | MeanScore 0.96
# Epoch 1705 | Loss 0.0273
# Epoch 1706 | Loss 0.0280
# Epoch 1707 | Loss 0.0253
# Epoch 1708 | Loss 0.0226
# Epoch 1709 | Loss 0.0181
# Epoch 1709 | MeanScore 0.98
# Epoch 1710 | Loss 0.0149
# Epoch 1711 | Loss 0.0103
# Epoch 1712 | Loss 0.0222
# Epoch 1713 | Loss 0.0115
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-b0c9baf55f54> in <module>()
#       1 loss, test_on_train = train_catch(catch = c, model = model, exp_replay = exp, num_games = 5000,
# ----> 2                                   batch_size = 10, test_every = 5, test_on_games = 100)
#       3 c.reset()
#       4 tests = test_catch(catch = c, model = model, test_on_games = 1000)
#
# <ipython-input-77-9488738e8ad0> in train_catch(catch, model, exp_replay, num_games, batch_size, per_random_act, num_actions, test_every, test_on_games)
#      75                     # Optimize the model
#      76                     optimizer.zero_grad()
# ---> 77                     loss.backward()
#      78                     for param in model.parameters():
#      79                         param.grad.data.clamp_(-1, 1)
#
# /Users/brandonjacques/anaconda/lib/python3.6/site-packages/torch/autograd/variable.py in backward(self, gradient, retain_graph, create_graph, retain_variables)
#     154                 Variable.
#     155         """
# --> 156         torch.autograd.backward(self, gradient, retain_graph, create_graph, retain_variables)
#     157
#     158     def register_hook(self, hook):
#
# /Users/brandonjacques/anaconda/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(variables, grad_variables, retain_graph, create_graph, retain_variables)
#      96
#      97     Variable._execution_engine.run_backward(
# ---> 98         variables, grad_variables, retain_graph)
#      99
#     100
#
# KeyboardInterrupt:

# %%
os.makedirs(".//configs", exist_ok=True)
os.makedirs(".//data", exist_ok=True)
os.makedirs(".//figs", exist_ok=True)

torch.save(model, "configs//" + test_name + ".ptm")

loss.to_csv("data//" + test_name + "_loss.csv", index=False)
test_on_train.to_csv("data//" + test_name + "_tests_in_training.csv", index=False)
tests.to_csv("data//" + test_name + "_tests.csv", index=False)
# Out:
# /Users/brandonjacques/anaconda/lib/python3.6/site-packages/torch/serialization.py:147: UserWarning: Couldn't retrieve source code for container of type DQN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# # WORKSPACE

# %%
x = torch.randn(10)

# %%
model2 = torch.load("configs//" + test_name + ".ptm")

# %%
a = action.data.max(1)[0].view(1, 1).numpy()[0]

# %%
inputs, targets = exp.sample(model, batch_size=10)

# %%
input_tm1 = c.observe(flatten=True, expand_dim=True)

# %%
temp = torch.from_numpy(input_tm1).type(Tensor)
temp = Variable(temp)
q = model2(temp).data.max(1)[1].view(1, 1).numpy()
action = q[0][0]

# %%
height = 11
width=13
m = False
q_size = 1
i=0
test_name = "RUN" + str(i) + "_Mask_" + str(int(m)) + "_13x11_Q" + str(q_size)+"_MLP"

c = Catch(screen_height=height, screen_width=width, output_buffer_size=q_size,
          game_over_conditions = {'ball_deletions': 10}, mask=m, ball_spawn_rate=11,)

# %%
queue = Queued_DQN(input_size, input_size*4, 3, 4)

# %%
c.act(1)
bb(Variable(torch.from_numpy(c.observe(flatten=True, expand_dim=True)).type(Tensor)))
# Out:
# Variable containing:
#  0.5667  0.2255  0.2753
# [torch.FloatTensor of size 1x3]

# %%
output = Variable(torch.from_numpy(c.observe(flatten=True, expand_dim=True)).type(Tensor))

# %%
output.requires_grad = False
